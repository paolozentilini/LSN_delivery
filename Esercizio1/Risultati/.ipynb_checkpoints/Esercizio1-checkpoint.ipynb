# %% [markdown]
# ## Laboratorio di simulazione numerica
# ### Esercitazione 1

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
M=1e6          
N=10000                

measurements = np.loadtxt("measurements.dat")
measurements1 = np.loadtxt("measurements1.dat")
chi = np.loadtxt("chi_squared_test.dat")

x = np.arange(N,M,N)

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.title("Expected value for a uniform random sample (M = 1e6, N=100).")
plt.errorbar(x, measurements.T[0]-0.5, yerr=measurements.T[1], color='green', alpha=0.5, label='Trend', linewidth=2)
plt.hlines(0,0,M, color='red', linestyle='--', label="Theoric expected value", linewidth=2, alpha=0.5)
plt.ylabel("<r>-0.5")
plt.xlabel("#throws")
plt.legend()
plt.grid(True)

plt.subplot(1,2,2)
plt.title("Expected value for a uniform random sample (M = 1e6, N=100).")
plt.hlines(0,0,M, color='red', linestyle='--', label="Theoric expected value", linewidth=2, alpha=0.5)
plt.errorbar(x,measurements1.T[0]-1/12,yerr=measurements1.T[1],color='blue', alpha=0.5, label='Trend', linewidth=2)
plt.xlabel('#throws')
plt.ylabel('<(r-0.5)^2>-1/12')
plt.legend()
plt.grid(True)

plt.show()

# %%
x = np.arange(0,100,1)
plt.figure(figsize=(15,5))
plt.title("$\chi^2$-analysis (M = 1e4, N=100).")
plt.hlines(100,0,100, color='red', label="Theoric expected value", linewidth=1.5, alpha=0.5)
plt.plot(x,chi, 'ro',color='orange',alpha=1, marker='.', markersize=15, label='$\chi^2$ measured')
plt.xlabel('#experiment')
plt.ylabel('$\chi^2$')
plt.legend()
plt.grid(True)

plt.show()

# %%
tlc = np.loadtxt("tlc.dat")
tlc1 = np.loadtxt("tlc1.dat")
tlc2 = np.loadtxt("tlc2.dat")
tlc3 = np.loadtxt("tlc3.dat")

# %%
plt.figure(figsize=(25,5))
plt.subplot(1,4,1)
plt.hist(tlc.T[0],bins=100, color='orange', alpha=1,density=True)
#plt.legend()
plt.grid(True)

plt.subplot(1,4,2)
plt.hist(tlc1.T[0],bins=100, color='orange', alpha=1,density=True)
#plt.legend()
plt.grid(True)

plt.subplot(1,4,3)
plt.hist(tlc2.T[0],bins=100, color='orange', alpha=1,density=True)
#plt.legend()
plt.grid(True)

plt.subplot(1,4,4)
plt.hist(tlc3.T[0],bins=100, color='orange', alpha=1,density=True)
#plt.legend()
plt.grid(True)

plt.show()

# %%
plt.figure(figsize=(16,5))
plt.subplot(2,2,1)
plt.hist(tlc.T[1],bins=100, color='orange', alpha=1,density=True)
#plt.legend()
plt.grid(True)

plt.subplot(2,2,2)
plt.hist(tlc1.T[1],bins=100, color='orange', alpha=1,density=True)
#plt.legend()
plt.grid(True)

plt.subplot(2,2,3)
plt.hist(tlc2.T[1],bins=100, color='orange', alpha=1,density=True)
#plt.legend()
plt.grid(True)

plt.subplot(2,2,4)
plt.hist(tlc3.T[1],bins=100, color='orange', alpha=1,density=True)
#plt.legend()
plt.grid(True)

plt.show()

# %%
plt.figure(figsize=(16,5))
plt.subplot(2,2,1)
plt.hist(tlc.T[2],bins=100, color='orange', alpha=1,density=True,range=(-10,10))
#plt.legend()
plt.grid(True)

plt.subplot(2,2,2)
plt.hist(tlc1.T[2],bins=100, color='orange', alpha=1,density=True,range=(-10,10))
#plt.legend()
plt.grid(True)

plt.subplot(2,2,3)
plt.hist(tlc2.T[2],bins=100, color='orange', alpha=1,density=True,range=(-10,10))
#plt.legend()
plt.grid(True)

plt.subplot(2,2,4)
plt.hist(tlc3.T[2],bins=100, color='orange', alpha=1,density=True,range=(-10,10))
#plt.legend()-10
plt.grid(True)

plt.show()

# %%
buffon= np.loadtxt("../Esercizio1.3/BuffonExperiment.dat")
x = np.arange(100,10000,100)

# %%
plt.title("Expected value for a uniform random sample (M = 1e6 N=100).")
plt.hlines(np.pi,0,10000, color='blue', linestyle='--', label="Theoric expected value", linewidth=1.5, alpha=0.5)
plt.errorbar(x,buffon.T[0],yerr=buffon.T[1],color='red', alpha=0.5, label='Trend', linewidth=2)
plt.xlabel('#throws')
plt.ylabel('<phi>')
plt.legend()
plt.grid(True)
